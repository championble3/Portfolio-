# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# C:\Users\tomai\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
data = pd.read_csv(r'C:\Users\tomai\Downloads\gender_classification_v7.csv')

# %%
data.head()
# Out:
#    long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0          1               11.8                 6.1          1          0
# 1          0               14.0                 5.4          0          0
# 2          0               11.8                 6.3          1          1
# 3          0               14.4                 6.1          0          1
# 4          1               13.5                 5.9          0          0
#
#    lips_thin  distance_nose_to_lip_long  gender
# 0          1                          1    Male
# 1          1                          0  Female
# 2          1                          1    Male
# 3          1                          1    Male
# 4          0                          0  Female

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5001 entries, 0 to 5000
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   long_hair                  5001 non-null   int64
#  1   forehead_width_cm          5001 non-null   float64
#  2   forehead_height_cm         5001 non-null   float64
#  3   nose_wide                  5001 non-null   int64
#  4   nose_long                  5001 non-null   int64
#  5   lips_thin                  5001 non-null   int64
#  6   distance_nose_to_lip_long  5001 non-null   int64
#  7   gender                     5001 non-null   object
# dtypes: float64(2), int64(5), object(1)
# memory usage: 312.7+ KB

# %%
data.describe()
# Out:
#          long_hair  forehead_width_cm  forehead_height_cm    nose_wide  \
# count  5001.000000        5001.000000         5001.000000  5001.000000
# mean      0.869626          13.181484            5.946311     0.493901
# std       0.336748           1.107128            0.541268     0.500013
# min       0.000000          11.400000            5.100000     0.000000
# 25%       1.000000          12.200000            5.500000     0.000000
# 50%       1.000000          13.100000            5.900000     0.000000
# 75%       1.000000          14.000000            6.400000     1.000000
# max       1.000000          15.500000            7.100000     1.000000
#
#          nose_long    lips_thin  distance_nose_to_lip_long
# count  5001.000000  5001.000000                5001.000000
# mean      0.507898     0.493101                   0.498900
# std       0.499988     0.500002                   0.500049
# min       0.000000     0.000000                   0.000000
# ...

# %%
def duplicates(data):
    if data[data.duplicated()==True].count()[0] == 0 :
        print('There are no duplicates in data')
    else:
        print('Deleting duplicates...')
        data = data.drop_duplicates(inplace = True)
        
duplicates(data)
# Out:
# Deleting duplicates...

# %%
data[data.duplicated()==True].count()[0] == 0
# Out:
# True

# %%
data.describe()
# Out:
#          long_hair  forehead_width_cm  forehead_height_cm    nose_wide  \
# count  3233.000000        3233.000000         3233.000000  3233.000000
# mean      0.822456          13.217198            5.966038     0.536344
# std       0.382188           1.115993            0.549789     0.498755
# min       0.000000          11.400000            5.100000     0.000000
# 25%       1.000000          12.300000            5.500000     0.000000
# 50%       1.000000          13.200000            5.900000     1.000000
# 75%       1.000000          14.100000            6.400000     1.000000
# max       1.000000          15.500000            7.100000     1.000000
#
#          nose_long    lips_thin  distance_nose_to_lip_long
# count  3233.000000  3233.000000                3233.000000
# mean      0.557686     0.538509                   0.545314
# std       0.496738     0.498592                   0.498019
# min       0.000000     0.000000                   0.000000
# ...

# %%
sns.countplot(data['gender'])
# Out:
# C:\Users\tomai\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
sns.heatmap(data.corr(),cmap='coolwarm',annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(data['forehead_height_cm'],data['forehead_width_cm'],hue=data['gender'])
plt.title('Forehead')
#As I can see, men have usually higher and widther forhead than women
# Out:
# C:\Users\tomai\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Forehead')

# %%
sns.pairplot(data,hue='gender')

# %%
data[data.isnull()==True].count()
# Out:
# long_hair                    0
# forehead_width_cm            0
# forehead_height_cm           0
# nose_wide                    0
# nose_long                    0
# lips_thin                    0
# distance_nose_to_lip_long    0
# gender                       0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# long_hair                    0
# forehead_width_cm            0
# forehead_height_cm           0
# nose_wide                    0
# nose_long                    0
# lips_thin                    0
# distance_nose_to_lip_long    0
# gender                       0
# dtype: int64

# %% [markdown]
# # Classifiers

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %% [markdown]
# LOGISTIC REGRESSION

# %%
X = data.drop('gender',axis=1)
y = data['gender']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

log_reg = LogisticRegression()
log_reg.fit(X_train,y_train)
preds_lr = log_reg.predict(X_test)
print(classification_report(y_test,preds_lr))
print(confusion_matrix(y_test,preds_lr))
print(f'Accuracy for Logistic Regression Model:{accuracy_score(y_test,preds_lr)}')
# Out:
#               precision    recall  f1-score   support
#
#       Female       0.96      0.95      0.95       457
#         Male       0.96      0.96      0.96       513
#
#     accuracy                           0.96       970
#    macro avg       0.96      0.96      0.96       970
# weighted avg       0.96      0.96      0.96       970
#
# [[434  23]
#  [ 20 493]]
# Accuracy for Logistic Regression Model:0.9556701030927836

# %% [markdown]
# DECISION TREE CLASSIFIER

# %%
X = data.drop('gender',axis=1)
y = data['gender']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

dec_tree = DecisionTreeClassifier()
dec_tree.fit(X_train,y_train)
preds_dt = dec_tree.predict(X_test)
print(classification_report(y_test,preds_dt))
print(confusion_matrix(y_test,preds_dt))
print(f'Accuracy for Decision Tree Model:{accuracy_score(y_test,preds_dt)}')
# Out:
#               precision    recall  f1-score   support
#
#       Female       0.94      0.94      0.94       457
#         Male       0.94      0.95      0.95       513
#
#     accuracy                           0.94       970
#    macro avg       0.94      0.94      0.94       970
# weighted avg       0.94      0.94      0.94       970
#
# [[428  29]
#  [ 27 486]]
# Accuracy for Decision Tree Model:0.9422680412371134

# %% [markdown]
# RANDOM FOREST CLASSIFIER

# %%
X = data.drop('gender',axis=1)
y = data['gender']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

rfc = RandomForestClassifier()
rfc.fit(X_train,y_train)
preds_rfc = rfc.predict(X_test)
print(classification_report(y_test,preds_rfc))
print(confusion_matrix(y_test,preds_rfc))
print(f'Accuracy for Random Forest Model:{accuracy_score(y_test,preds_rfc)}')
# Out:
#               precision    recall  f1-score   support
#
#       Female       0.94      0.94      0.94       457
#         Male       0.95      0.95      0.95       513
#
#     accuracy                           0.94       970
#    macro avg       0.94      0.94      0.94       970
# weighted avg       0.94      0.94      0.94       970
#
# [[431  26]
#  [ 28 485]]
# Accuracy for Random Forest Model:0.9443298969072165

# %% [markdown]
# SVM CLASSIFIER

# %%
X = data.drop('gender',axis=1)
y = data['gender']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

svm = SVC()
svm.fit(X_train,y_train)
svm_ = svm.predict(X_test)

print(classification_report(y_test,svm_))
print(confusion_matrix(y_test,svm_))
print(f'Accuracy for SVM Model:{accuracy_score(y_test,svm_)}')
# Out:
#               precision    recall  f1-score   support
#
#       Female       0.96      0.95      0.95       457
#         Male       0.95      0.96      0.96       513
#
#     accuracy                           0.95       970
#    macro avg       0.95      0.95      0.95       970
# weighted avg       0.95      0.95      0.95       970
#
# [[433  24]
#  [ 20 493]]
# Accuracy for SVM Model:0.954639175257732

# %% [markdown]
# SVM CLASSIFIER WITH HYPERPARAMETER TUNING USING GRID SEARCH

# %%
param_grid = {'C': [1,2,3,4,5,10,15], 'gamma': [0.00001,0.0001,0.001,0.01,0.1,1]}
X = data.drop('gender',axis=1)
y = data['gender']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

grid_search = GridSearchCV(SVC(),param_grid,verbose=4)
grid_search.fit(X_train,y_train)
grid_search.best_params_
preds_svm = grid_search.predict(X_test)
# Out:
# Fitting 5 folds for each of 42 candidates, totalling 210 fits
# [CV 1/5] END ..................C=1, gamma=1e-05;, score=0.561 total time=   0.1s
# [CV 2/5] END ..................C=1, gamma=1e-05;, score=0.561 total time=   0.1s
# [CV 3/5] END ..................C=1, gamma=1e-05;, score=0.561 total time=   0.1s
# [CV 4/5] END ..................C=1, gamma=1e-05;, score=0.562 total time=   0.1s
# [CV 5/5] END ..................C=1, gamma=1e-05;, score=0.562 total time=   0.1s
# [CV 1/5] END .................C=1, gamma=0.0001;, score=0.561 total time=   0.1s
# [CV 2/5] END .................C=1, gamma=0.0001;, score=0.561 total time=   0.1s
# [CV 3/5] END .................C=1, gamma=0.0001;, score=0.561 total time=   0.1s
# [CV 4/5] END .................C=1, gamma=0.0001;, score=0.562 total time=   0.1s
# [CV 5/5] END .................C=1, gamma=0.0001;, score=0.562 total time=   0.1s
# [CV 1/5] END ..................C=1, gamma=0.001;, score=0.949 total time=   0.1s
# ...

# %%
print(classification_report(y_test,preds_svm))
print(confusion_matrix(y_test,preds_svm))
print(f'Accuracy for SVM Model(with hyperparameter tuning):{accuracy_score(y_test,preds_svm)}')
# Out:
#               precision    recall  f1-score   support
#
#       Female       0.96      0.96      0.96       457
#         Male       0.97      0.96      0.96       513
#
#     accuracy                           0.96       970
#    macro avg       0.96      0.96      0.96       970
# weighted avg       0.96      0.96      0.96       970
#
# [[440  17]
#  [ 20 493]]
# Accuracy for SVM Model(with hyperparameter tuning):0.9618556701030928

# %% [markdown]
# I've experimented with several models to predict gender, and it seems that the SVM model, especially after hyperparameter tuning, performed the best. However, it required the most time to train. On the other hand, the logistic regression model also achieved impressive results. The choice of the best model for evaluation ultimately depends on our specific goals and priorities.
